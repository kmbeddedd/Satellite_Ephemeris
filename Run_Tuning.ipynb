# %%
# !gdown 1NVFmMf2n40at-GBjWFyUA7lCAFmzi_Z6 -O FINAL_Data.csv
# !gdown 1-6RFTRiSe9tEbkuEV6A_-RuqOecILctk -O gnss_forecast.py
# !gdown 1BfjgtY7ociihndFgH2n5f7aVV89kEFWy -O tune.py
# !pip install optuna
# !python tune.py
